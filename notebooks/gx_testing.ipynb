# %%
import json # Path to your saved expectation suite JSON file
import json
from great_expectations.core.expectation_suite import ExpectationSuite


expectation_suite_path = '/home/sachin/DSP/car_price_prediction/gx/my_expectations.json'

# Load the JSON file
with open(expectation_suite_path, 'r') as f:
    expectation_suite_dict = json.load(f)

# Convert the dictionary to an ExpectationSuite object
expectation_suite = ExpectationSuite(**expectation_suite_dict)

# %%
import pandas as pd
from great_expectations.dataset.pandas_dataset import PandasDataset


df =pd.read_csv('/home/sachin/DSP/airflow-spike-master/input_data/raw-data/data_chunk_609.csv')
# Assuming `df` is your Pandas DataFrame you want to validate
dataset = PandasDataset(df, expectation_suite=expectation_suite)

# Perform validation
results = dataset.validate()

# %%
results
# Out:
# {
#   "success": true,
#   "results": [
#     {
#       "success": true,
#       "expectation_config": {
#         "expectation_type": "expect_column_values_to_be_in_set",
#         "kwargs": {
#           "column": "fuel",
#           "value_set": [
#             "Petrol",
#             "Diesel",
#             "CNG",
#             "Electric"
#           ]
#         },
#         "meta": {}
#       },
#       "result": {
#         "element_count": 8,
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "expectation_type": "expect_column_values_to_be_between",
#         "kwargs": {
#           "column": "year",
#           "min_value": 1900,
#           "max_value": 2024
#         },
#         "meta": {}
#       },
#       "result": {
#         "element_count": 8,
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "expectation_type": "expect_column_values_to_be_between",
#         "kwargs": {
#           "column": "selling_price",
#           "min_value": 0,
#           "max_value": 1000000000.0
#         },
#         "meta": {}
#       },
#       "result": {
#         "element_count": 8,
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "expectation_type": "expect_column_values_to_be_between",
#         "kwargs": {
#           "column": "km_driven",
#           "min_value": 0,
#           "max_value": 1000000.0
#         },
#         "meta": {}
#       },
#       "result": {
#         "element_count": 8,
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "expectation_type": "expect_column_values_to_be_in_set",
#         "kwargs": {
#           "column": "seller_type",
#           "value_set": [
#             "Individual",
#             "Dealer"
#           ]
#         },
#         "meta": {}
#       },
#       "result": {
#         "element_count": 8,
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "expectation_type": "expect_column_values_to_be_in_set",
#         "kwargs": {
#           "column": "transmission",
#           "value_set": [
#             "Manual",
#             "Automatic"
#           ]
#         },
#         "meta": {}
#       },
#       "result": {
#         "element_count": 8,
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "expectation_type": "expect_column_values_to_match_regex",
#         "kwargs": {
#           "column": "owner",
#           "regex": "^[a-zA-Z\\s]+$"
#         },
#         "meta": {}
#       },
#       "result": {
#         "element_count": 8,
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "expectation_type": "expect_column_values_to_be_between",
#         "kwargs": {
#           "column": "mileage",
#           "min_value": 0,
#           "max_value": 50
#         },
#         "meta": {}
#       },
#       "result": {
#         "element_count": 8,
#         "missing_count": 1,
#         "missing_percent": 12.5,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "expectation_type": "expect_column_values_to_be_between",
#         "kwargs": {
#           "column": "engine",
#           "min_value": 0,
#           "max_value": 10000
#         },
#         "meta": {}
#       },
#       "result": {
#         "element_count": 8,
#         "missing_count": 1,
#         "missing_percent": 12.5,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "expectation_type": "expect_column_values_to_be_between",
#         "kwargs": {
#           "column": "max_power",
#           "min_value": 0,
#           "max_value": 1000
#         },
#         "meta": {}
#       },
#       "result": {
#         "element_count": 8,
#         "missing_count": 1,
#         "missing_percent": 12.5,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "expectation_type": "expect_column_values_to_be_between",
#         "kwargs": {
#           "column": "seats",
#           "min_value": 1,
#           "max_value": 10
#         },
#         "meta": {}
#       },
#       "result": {
#         "element_count": 8,
#         "missing_count": 1,
#         "missing_percent": 12.5,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "expectation_type": "expect_column_values_to_match_regex",
#         "kwargs": {
#           "column": "car_company_name",
#           "regex": "^[a-zA-Z\\s]+$"
#         },
#         "meta": {}
#       },
#       "result": {
#         "element_count": 8,
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       }
#     }
#   ],
#   "evaluation_parameters": {},
#   "statistics": {
#     "evaluated_expectations": 12,
#     "successful_expectations": 12,
#     "unsuccessful_expectations": 0,
#     "success_percent": 100.0
#   },
#   "meta": {
#     "great_expectations_version": "0.18.12",
#     "expectation_suite_name": "default",
#     "run_id": {
#       "run_name": null,
#       "run_time": "2024-03-29T13:37:40.555267+00:00"
#     },
#     "batch_kwargs": {
#       "ge_batch_id": "83845fca-edd1-11ee-bc1a-b18935325166"
#     },
#     "batch_markers": {},
#     "batch_parameters": {},
#     "validation_time": "20240329T133740.555132Z",
#     "expectation_suite_meta": {
#       "great_expectations_version": "0.18.12"
#     }
#   }
# }
