# %%
import pandas as pd
import random
import numpy as np

# Load the CSV file
df = pd.read_csv("/home/sachin/DSP/car_price_prediction/data/car_details.csv")
 
# Function to introduce random errors with a 2% chance
def introduce_error(value):
    if random.random() < 0.02:  # 2% chance of introducing error
        return 'Error'
    return value
 
# Function to introduce random errors in 'year' column
def introduce_year_error(value):
    if value == 'Error':
        return str(random.randint(1, 10))  # Convert integer to string
    return value
 
# Function to introduce error in car_company_name column in random rows
def introduce_error_car_company_name(row):
    if random.random() < 0.02:  # 2% chance of introducing error
        return row['name'].split()[1]
    return row['car_company_name']
 
# Function to replace 'Error' with random values or NaN in mileage and seats columns
def replace_error_value(value):
    if value == 'Error':
        return random.choice([f'{random.randint(1, 50)} kmpl', np.nan])
    return value
 
# Function to introduce errors in the price column
def introduce_price_error(value):
    if value == 'Error':
        return random.choice([f'{random.randint(1, 30)} Lakhs', 'Ask for Price'])
    return value
 
# Function to introduce errors in the engine column
def introduce_engine_error(value):
    if value == 'Error':
        return random.choice([f'{random.randint(800, 5000)} CC', np.nan])
    return value
 
# Function to introduce errors in the mileage column
def introduce_mileage_error(value):
    if value == 'Error':
        return random.choice([f'{random.randint(1, 50)} kmpl', 'Unknown'])
    return value
 
# Function to introduce errors in the seats column
def introduce_seats_error(value):
    if value == 'Error':
        return random.choice([f'{random.randint(2, 9)} seats', np.nan])
    return value
 
# Apply error functions to respective columns
df['year'] = df['year'].apply(introduce_error).apply(introduce_year_error)
df['car_company_name'] = df.apply(introduce_error_car_company_name, axis=1)
df['fuel'] = df['fuel'].apply(introduce_error).apply(lambda x: 'Electric' if x == 'Error' else x)
df['seller_type'] = df['seller_type'].apply(introduce_error).apply(lambda x: 'Partnership' if x == 'Error' else x)
df['transmission'] = df['transmission'].apply(introduce_error).apply(lambda x: 'Ai' if x == 'Error' else x)
df['owner'] = df['owner'].apply(introduce_error).apply(lambda x: 'Rent' if x == 'Error' else x)
df['engine'] = df['engine'].apply(introduce_error).apply(introduce_engine_error)
df['mileage'] = df['mileage'].apply(introduce_error).apply(introduce_mileage_error)
df['seats'] = df['seats'].apply(introduce_error).apply(introduce_seats_error)
 
# Save the modified DataFrame to a new CSV file
df.to_csv('/home/sachin/DSP/car_price_prediction/data/car_details.csv', index=False)
